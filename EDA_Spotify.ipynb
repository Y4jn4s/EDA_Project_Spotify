# %% [markdown]
# ### IMPORTING ALL FRAMEWORKS

# %%
import os, warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (10, 6)

DATA_FILE = 'SpotifyFeatures.csv'

# %% [markdown]
# ### LOAD THE DATASET

# %%
df = pd.read_csv(DATA_FILE, low_memory=False)
print("Shape:", df.shape)

display(df.head())
display(df.info())
display(df.describe(include='all').T)
# Out:
# Shape: (232725, 18)
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   genre             232725 non-null  object
#  1   artist_name       232725 non-null  object
#  2   track_name        232724 non-null  object
#  3   track_id          232725 non-null  object
#  4   popularity        232725 non-null  int64
#  5   acousticness      232725 non-null  float64
#  6   danceability      232725 non-null  float64
#  7   duration_ms       232725 non-null  int64
#  8   energy            232725 non-null  float64
#  9   instrumentalness  232725 non-null  float64
#  10  key               232725 non-null  object
#  11  liveness          232725 non-null  float64
#  12  loudness          232725 non-null  float64
#  13  mode              232725 non-null  object
#  14  speechiness       232725 non-null  float64
#  15  tempo             232725 non-null  float64
#  16  time_signature    232725 non-null  object
#  17  valence           232725 non-null  float64
# dtypes: float64(9), int64(2), object(7)
# memory usage: 32.0+ MB
# None
#                      count  unique                     top    freq  \
# genre               232725      27                  Comedy    9681
# artist_name         232725   14564          Giuseppe Verdi    1394
# track_name          232724  148614                    Home     100
# track_id            232725  176774  0UE0RhnRaEYsiYgXpyLoZc       8
# popularity        232725.0     NaN                     NaN     NaN
# acousticness      232725.0     NaN                     NaN     NaN
# danceability      232725.0     NaN                     NaN     NaN
# duration_ms       232725.0     NaN                     NaN     NaN
# energy            232725.0     NaN                     NaN     NaN
# instrumentalness  232725.0     NaN                     NaN     NaN
# key                 232725      12                       C   27583
# liveness          232725.0     NaN                     NaN     NaN
# loudness          232725.0     NaN                     NaN     NaN
# mode                232725       2                   Major  151744
# speechiness       232725.0     NaN                     NaN     NaN
# tempo             232725.0     NaN                     NaN     NaN
# time_signature      232725       5                     4/4  200760
# valence           232725.0     NaN                     NaN     NaN
#
#                            mean            std      min       25%       50%  \
# genre                       NaN            NaN      NaN       NaN       NaN
# artist_name                 NaN            NaN      NaN       NaN       NaN
# track_name                  NaN            NaN      NaN       NaN       NaN
# track_id                    NaN            NaN      NaN       NaN       NaN
# popularity            41.127502      18.189948      0.0      29.0      43.0
# acousticness            0.36856       0.354768      0.0    0.0376     0.232
# danceability           0.554364       0.185608   0.0569     0.435     0.571
# duration_ms       235122.339306  118935.909299  15387.0  182857.0  220427.0
# energy                 0.570958       0.263456  0.00002     0.385     0.605
# instrumentalness       0.148301       0.302768      0.0       0.0  0.000044
# key                         NaN            NaN      NaN       NaN       NaN
# liveness               0.215009       0.198273  0.00967    0.0974     0.128
# loudness              -9.569885       5.998204  -52.457   -11.771    -7.762
# mode                        NaN            NaN      NaN       NaN       NaN
# speechiness            0.120765       0.185518   0.0222    0.0367    0.0501
# tempo                117.666585      30.898907   30.379    92.959   115.778
# time_signature              NaN            NaN      NaN       NaN       NaN
# valence                0.454917       0.260065      0.0     0.237     0.444
#
#                        75%        max
# genre                  NaN        NaN
# artist_name            NaN        NaN
# track_name             NaN        NaN
# track_id               NaN        NaN
# popularity            55.0      100.0
# acousticness         0.722      0.996
# danceability         0.692      0.989
# duration_ms       265768.0  5552917.0
# energy               0.787      0.999
# instrumentalness    0.0358      0.999
# key                    NaN        NaN
# liveness             0.264        1.0
# loudness            -5.501      3.744
# mode                   NaN        NaN
# speechiness          0.105      0.967
# tempo              139.054    242.903
# time_signature         NaN        NaN
# valence               0.66        1.0

# %% [markdown]
# ### CLEANING AND FORMATTING

# %%
df.columns = [c.strip() for c in df.columns]

nulls = df.isna().sum().sort_values(ascending=False)
print('Top null counts:')
display(nulls.head(10))

if 'popularity' in df.columns:
    df['popularity'] = pd.to_numeric(df['popularity'], errors='coerce')

if 'duration_ms' in df.columns:
    df['duration_min'] = pd.to_numeric(df['duration_ms'], errors='coerce')/60000.0

if 'release_date' in df.columns:
    df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce', infer_datetime_format=True)
    df['release_year'] = df['release_date'].dt.year
elif 'year' in df.columns:
    df['release_year'] = pd.to_numeric(df['year'], errors='coerce')

if 'track_genre' in df.columns:
    df['track_genre'] = df['track_genre'].astype(str).str.lower()

print('Finished basic cleaning steps.')
display(df[['track_name','artist_name','popularity']].head())
# Out:
# Top null counts:
# track_name          1
# genre               0
# artist_name         0
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# dtype: int64
# Finished basic cleaning steps.
#                          track_name        artist_name  popularity
# 0       C'est beau de faire un Show     Henri Salvador           0
# 1  Perdu d'avance (par Gad Elmaleh)  Martin & les fées           1
# 2    Don't Let Me Be Lonely Tonight    Joseph Williams           3
# 3    Dis-moi Monsieur Gordon Cooper     Henri Salvador           0
# 4                         Ouverture       Fabien Nataf           4

# %% [markdown]
# ### UNIVARIATE ANALYSIS
# #### AUDIO FEATURE DISTRIBUTIONS, CATEGORICAL COUNTS

# %%
num_cols = [c for c in ['danceability','energy','loudness','speechiness','acousticness','instrumentalness','liveness','valence','tempo','duration_min','popularity'] if c in df.columns]

for col in num_cols:
    plt.figure()
    df[col].dropna().hist(bins=50)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

# %%
if 'track_genre' in df.columns:
    plt.figure(figsize=(12,5))
    df['track_genre'].value_counts().head(20).plot(kind='bar')
    plt.title('Top 20 Genres (by count)')
    plt.xlabel('Genre')
    plt.ylabel('Count')
    plt.tight_layout()
    plt.show()

# Top artists
plt.figure(figsize=(12,5))
top_artists = df['artist_name'].value_counts().head(20)
top_artists.plot(kind='bar')
plt.title('Top 20 Artists (by track count)')
plt.xlabel('Artist')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### POPULARITY ANALYSIS

# %%
if 'popularity' in df.columns:
    plt.figure()
    df['popularity'].dropna().hist(bins=50)
    plt.title('Popularity distribution (0-100)')
    plt.xlabel('Popularity')
    plt.ylabel('Count')
    plt.show()

# Correlation between audio features and popularity
feature_cols = [c for c in ['danceability','energy','loudness','speechiness','acousticness','instrumentalness','liveness','valence','tempo','duration_min'] if c in df.columns]
if 'popularity' in df.columns and len(feature_cols)>0:
    corr_df = df[feature_cols + ['popularity']].corr(numeric_only=True)
    display(corr_df['popularity'].sort_values(ascending=False))
    top_pos = corr_df['popularity'].drop('popularity').abs().sort_values(ascending=False).head(4).index.tolist()
    for col in top_pos:
        plt.figure()
        plt.scatter(df[col], df['popularity'], alpha=0.3, s=10)
        plt.xlabel(col)
        plt.ylabel('popularity')
        plt.title(f'Popularity vs {col}')
        plt.tight_layout()
        plt.show()
# Out:
# popularity          1.000000
# loudness            0.363011
# danceability        0.256564
# energy              0.248922
# tempo               0.081039
# valence             0.060076
# duration_min        0.002348
# speechiness        -0.151076
# liveness           -0.167995
# instrumentalness   -0.210983
# acousticness       -0.381295
# Name: popularity, dtype: float64

# %%
if 'release_year' in df.columns:
    # Popularity by year
    yearly = df.groupby('release_year', as_index=False)['popularity'].mean().dropna()
    plt.plot(yearly['release_year'], yearly['popularity'], marker='o')
    plt.title('Avg Popularity by Year'); plt.xlabel('Year'); plt.ylabel('Popularity')
    plt.grid(True, ls='--', alpha=0.6); plt.show()

    # Feature trends
    feats = [f for f in ['danceability','energy','tempo','valence'] if f in df.columns]
    if feats:
        yearly_feats = df.groupby('release_year')[feats].mean()
        for f in feats:
            plt.plot(yearly_feats.index, yearly_feats[f], label=f)
        plt.title('Audio Feature Trends'); plt.xlabel('Year'); plt.ylabel('Mean Value')
        plt.legend(); plt.grid(True, ls='--', alpha=0.6); plt.show()
else:
    print(' No release_year column — skipping.')
# Out:
#  No release_year column — skipping.

# %% [markdown]
# ### TOP HITS

# %%
if 'popularity' in df.columns:
    df_unique = df.sort_values('popularity', ascending=False).drop_duplicates(
        subset=['track_name', 'artist_name'], keep='first'
    )

    top50 = df_unique.sort_values('popularity', ascending=False).head(50)
    bottom50 = df_unique.sort_values('popularity', ascending=True).head(50)

    display(top50[['track_name','artist_name','popularity'] + 
                  [c for c in feature_cols if c in top50.columns]].head(10))

    # Feature fingerprint
    fingerprint = pd.DataFrame({
        'Top 50 (mean)': top50[feature_cols].mean(),
        'Bottom 50 (mean)': bottom50[feature_cols].mean()
    })

    plt.figure(figsize=(8,6))
    sns.heatmap(fingerprint, annot=True, fmt='.2f', cmap="coolwarm", cbar=True)
    plt.title('Feature Fingerprint: Top 50 vs Bottom 50 (Unique Songs)')
    plt.show()
# Out:
#                                            track_name    artist_name  \
# 107804                                        7 rings  Ariana Grande
# 107803                                           Wow.    Post Malone
# 107802       break up with your girlfriend, i'm bored  Ariana Grande
# 138918                                      Con Calma   Daddy Yankee
# 107810         Dancing With A Stranger (with Normani)      Sam Smith
# 92824                                      Without Me         Halsey
# 86953   Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 107812                                        Happier     Marshmello
# 107875                                  Calma - Remix     Pedro Capó
# 9037                                 Sweet but Psycho        Ava Max
#
#         popularity  danceability  energy  loudness  speechiness  acousticness  \
# 107804         100         0.725   0.321   -10.744       0.3230        0.5780
# 107803          99         0.833   0.539    -7.399       0.1780        0.1630
# 107802          99         0.726   0.554    -5.290       0.0917        0.0421
# 138918          98         0.737   0.860    -2.652       0.0593        0.1100
# 107810          97         0.741   0.520    -7.513       0.0656        0.4500
# 92824           97         0.752   0.488    -7.050       0.0705        0.2970
# 86953           97         0.760   0.479    -5.574       0.0466        0.5560
# 107812          97         0.687   0.792    -2.749       0.0452        0.1910
# 107875          97         0.826   0.773    -4.218       0.0524        0.3230
# 9037            97         0.719   0.704    -4.724       0.0476        0.0691
#
#         instrumentalness  liveness  valence    tempo  duration_min
# 107804          0.000000    0.0884    0.319   70.142      2.977333
# 107803          0.000002    0.1010    0.385   99.947      2.492000
# 107802          0.000000    0.1060    0.335  169.999      3.174000
# 138918          0.000002    0.0574    0.656   93.989      3.220450
# 107810          0.000002    0.2220    0.347  102.998      2.850500
# 92824           0.000009    0.0936    0.533  136.041      3.361017
# 86953           0.000000    0.0703    0.913   89.911      2.634000
# 107812          0.000000    0.1670    0.671  100.015      3.571500
# 107875          0.000000    0.1430    0.761  126.899      3.970000
# 9037            0.000000    0.1660    0.628  133.002      3.123933

# %% [markdown]
# ### CLUSTERING SONGS BY AUDIO FEATURES

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

cluster_cols = feature_cols
if cluster_cols:
    X = df[cluster_cols].dropna()              
    scaler = StandardScaler()
    Xs = scaler.fit_transform(X)               
    k = 4
    km = KMeans(n_clusters=k, random_state=42, n_init=10)
    km.fit(Xs)
    labels = km.labels_

    # Inverse-transform cluster centers back to original feature space
    centers = pd.DataFrame(scaler.inverse_transform(km.cluster_centers_), columns=cluster_cols)
    display(centers.T)

    preview = pd.DataFrame({
        'track_name': df.loc[X.index, 'track_name'].values,
        'artist_name': df.loc[X.index, 'artist_name'].values,
        'cluster': labels
    }).reset_index(drop=True).head(200)
    print('Assigned cluster labels to first 200 songs for preview:')
    display(preview.head(10))
else:
    print('No feature columns found for clustering.')
# Out:
#                            0           1           2          3
# danceability        0.616004    0.288296    0.546987   0.562004
# energy              0.734911    0.163989    0.377138   0.664174
# loudness           -6.261715  -20.727705  -11.131420 -11.954815
# speechiness         0.100904    0.046495    0.072070   0.873867
# acousticness        0.125665    0.850254    0.620093   0.785868
# instrumentalness    0.068378    0.676139    0.084776   0.001362
# liveness            0.207674    0.154093    0.172124   0.729809
# valence             0.554645    0.148986    0.385883   0.414342
# tempo             124.404728  102.401021  113.121551  98.276715
# duration_min        3.867060    4.388808    3.764718   4.066146
# Assigned cluster labels to first 200 songs for preview:
#                                           track_name          artist_name  \
# 0                        C'est beau de faire un Show       Henri Salvador
# 1                   Perdu d'avance (par Gad Elmaleh)    Martin & les fées
# 2                     Don't Let Me Be Lonely Tonight      Joseph Williams
# 3                     Dis-moi Monsieur Gordon Cooper       Henri Salvador
# 4                                          Ouverture         Fabien Nataf
# 5                     Le petit souper aux chandelles       Henri Salvador
# 6  Premières recherches (par Paul Ventimila, Lori...    Martin & les fées
# 7                                      Let Me Let Go          Laura Mayne
# 8                                              Helka               Chorus
# 9                          Les bisous des bisounours  Le Club des Juniors
#
#    cluster
# 0        0
# 1        0
# 2        2
# 3        2
# 4        2
# 5        2
# 6        3
# 7        2
# 8        0
# 9        0
